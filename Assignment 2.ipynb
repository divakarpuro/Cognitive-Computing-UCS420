# %% [markdown]
# 1. Take your roll number. Extract its individual digits, and multiply each digit by 10 to form your list L (10
# numbers in list now).
# i. Print L
# ii. Add two numbers of your choice to L — one using append() and one using insert() at a specific position.
# Print L after each and explain in a comment what changed.
# iii. Remove two elements from L — one using remove() and one using pop(). Print L after each.
# iv. Sort L in ascending order using sort(), then descending order using sort(reverse=True). Print both.
# v. Use slicing to print the first three elements and the last three elements of L in a single line each.
# vi. Use list comprehension to create a new list containing only the elements of L that are greater than the
# average of L.

# %%
roll_number = 1024170422

L = [int(digit) * 10 for digit in str(roll_number)]

print("i. Original L:", L)

L.append(50)
print(" after 50 :", L)


L.insert(2, 70)
print("after 70 at 2 :", L)


L.remove(50)
print("after removing 50 :", L)

removed = L.pop(0)
print("pop :", L)
print("Element removed using pop():", removed)

L.sort()
print("Ascending order:", L)

L.sort(reverse=True)
print("Descending order:", L)

print("First three elements:", L[:3])
print("Last three elements:", L[-3:])


average = sum(L) / len(L)

greater_than_average = [x for x in L if x > average]

print("Average:", average)
print("Elements greater than average:", greater_than_average)
# Out:
# i. Original L: [10, 0, 20, 40, 10, 70, 0, 40, 20, 20]
#  after 50 : [10, 0, 20, 40, 10, 70, 0, 40, 20, 20, 50]
# after 70 at 2 : [10, 0, 70, 20, 40, 10, 70, 0, 40, 20, 20, 50]
# after removing 50 : [10, 0, 70, 20, 40, 10, 70, 0, 40, 20, 20]
# pop : [0, 70, 20, 40, 10, 70, 0, 40, 20, 20]
# Element removed using pop(): 10
# Ascending order: [0, 0, 10, 20, 20, 20, 40, 40, 70, 70]
# Descending order: [70, 70, 40, 40, 20, 20, 20, 10, 0, 0]
# First three elements: [70, 70, 40]
# Last three elements: [10, 0, 0]
# Average: 29.0
# Elements greater than average: [70, 70, 40, 40]

# %% [markdown]
# 2. Create a tuple named scores containing 8 marks: use the first 8 values from your list L in Q1.
# i. Find the highest score and its index in the tuple, and the lowest score and how many times it appears.
# ii. Reverse the tuple and return the result as a list (tuples themselves cannot be reversed in place —
# explain why in a one-line comment, referring to tuple immutability).
# iii. Ask the user to input a score. Print its first occurrence index if present in the tuple, or a not present
# message if not.
# iv. Attempt to change one element of the tuple directly (e.g., scores[0] = 100). Run it, capture the error
# Python raises, and explain in one line why this happens and how it differs from a list.
# v. Unpack the tuple into a first score, a second score, and all remaining scores using the * operator in a
# single line of unpacking.

# %%
scores = tuple(L[:8])

print("Scores tuple:", scores)

highest_score = max(scores)
highest_index = scores.index(highest_score)

lowest_score = min(scores)
lowest_count = scores.count(lowest_score)

print("Highest score:", highest_score)
print("Index of highest score:", highest_index)

print("Lowest score:", lowest_score)
print("Number of times lowest score appears:", lowest_count)

reversed_scores = list(reversed(scores))

print("Reversed tuple as list:", reversed_scores)

search = int(input("Enter a score to search: "))

if search in scores:
    print("First occurrence index:", scores.index(search))
else:
    print("Score is not present in the tuple.")

try:
    scores[0] = 100
except TypeError as error:
    print("Error:", error)


first_score, second_score, *remaining_scores = scores

print("First score:", first_score)
print("Second score:", second_score)
print("Remaining scores:", remaining_scores)
# Out:
# Scores tuple: (70, 70, 40, 40, 20, 20, 20, 10)
# Highest score: 70
# Index of highest score: 0
# Lowest score: 10
# Number of times lowest score appears: 1
# Reversed tuple as list: [10, 20, 20, 20, 40, 40, 70, 70]
# Score is not present in the tuple.
# Error: 'tuple' object does not support item assignment
# First score: 70
# Second score: 70
# Remaining scores: [40, 40, 20, 20, 20, 10]

# %% [markdown]
# 3. Set the random seed to your own roll number using random.seed(your_roll_number) before generating
# your numbers — this keeps your list random-looking but reproducible and unique to you (a different seed
# produces a different list, so this cannot be copied from a classmate).
# i. Generate a list of 100 random numbers between 100 and 900 (inclusive).
# ii. Count and print all odd numbers in the list.
# iii. Count and print all even numbers in the list.
# iv. Count and print all prime numbers in the list, and additionally build the actual list of prime numbers
# found using list comprehension.
# v. Print the number that occurs most frequently in your list, and how many times it occurs.

# %%
import random
from collections import Counter

random.seed(1024170422)

numbers = [random.randint(100, 900) for _ in range(100)]

print("100 Random Numbers:")
print(numbers)

def is_prime(n):
    if n < 2:
        return False

    for i in range(2, int(n ** 0.5) + 1):
        if n % i == 0:
            return False

    return True


odd_numbers = [x for x in numbers if x % 2 != 0]

print("Number of odd numbers:", len(odd_numbers))
print("Odd numbers:", odd_numbers)

even_numbers = [x for x in numbers if x % 2 == 0]

print("Number of even numbers:", len(even_numbers))
print("Even numbers:", even_numbers)

prime_numbers = [x for x in numbers if is_prime(x)]

print("Number of prime numbers:", len(prime_numbers))
print("Prime numbers:", prime_numbers)


frequency = Counter(numbers)

most_frequent_number, highest_frequency = frequency.most_common(1)[0]

print("Most frequent number:", most_frequent_number)
print("Number of occurrences:", highest_frequency)
# Out:
# 100 Random Numbers:
# [577, 501, 203, 550, 248, 695, 136, 183, 505, 176, 403, 140, 184, 108, 448, 266, 815, 445, 565, 694, 897, 770, 767, 524, 257, 525, 617, 476, 373, 697, 529, 633, 514, 331, 719, 788, 759, 225, 278, 346, 896, 236, 429, 640, 598, 812, 364, 368, 419, 499, 786, 833, 528, 334, 889, 875, 504, 587, 670, 836, 243, 541, 271, 375, 628, 594, 893, 120, 278, 805, 124, 676, 336, 886, 227, 401, 587, 658, 784, 535, 161, 695, 503, 796, 825, 408, 577, 407, 417, 564, 279, 746, 436, 197, 775, 802, 176, 333, 777, 366]
# Number of odd numbers: 52
# Odd numbers: [577, 501, 203, 695, 183, 505, 403, 815, 445, 565, 897, 767, 257, 525, 617, 373, 697, 529, 633, 331, 719, 759, 225, 429, 419, 499, 833, 889, 875, 587, 243, 541, 271, 375, 893, 805, 227, 401, 587, 535, 161, 695, 503, 825, 577, 407, 417, 279, 197, 775, 333, 777]
# Number of even numbers: 48
# Even numbers: [550, 248, 136, 176, 140, 184, 108, 448, 266, 694, 770, 524, 476, 514, 788, 278, 346, 896, 236, 640, 598, 812, 364, 368, 786, 528, 334, 504, 670, 836, 628, 594, 120, 278, 124, 676, 336, 886, 658, 784, 796, 408, 564, 746, 436, 802, 176, 366]
# Number of prime numbers: 17
# Prime numbers: [577, 257, 617, 373, 331, 719, 419, 499, 587, 541, 271, 227, 401, 587, 503, 577, 197]
# Most frequent number: 577
# Number of occurrences: 2

# %% [markdown]
# 4. Using the same 8 digits of your roll number from Q1 (before multiplying by 10), create set A = {digit × 7 for
# each digit} and set B = {digit × 9 for each digit}. Print both sets.
# vi. Find the union of A and B — all unique values across both sets.
# vii. Find the intersection of A and B — values common to both.
# viii. Find A − B and B − A separately (not combined) using difference(), and explain in one line how this
# differs from symmetric_difference().
# ix. Find the symmetric difference of A and B.
# x. Check whether A is a subset of B, and whether B is a superset of A, using issubset() and issuperset().
# xi. Ask the user to input a value X. Remove X from set A if present using discard() (not remove()) — explain
# in one line why discard() is safer than remove() when you're not sure the value exists.

# %%
roll_number = 1024170422

digits = [int(digit) for digit in str(roll_number)]

A = {digit * 7 for digit in digits}
B = {digit * 9 for digit in digits}

print("Set A:", A)
print("Set B:", B)

union_set = A.union(B)

print("Union of A and B:", union_set)

intersection_set = A.intersection(B)

print("Intersection of A and B:", intersection_set)

A_minus_B = A.difference(B)
B_minus_A = B.difference(A)

print("A - B:", A_minus_B)
print("B - A:", B_minus_A)

symmetric_difference = A.symmetric_difference(B)

print("Symmetric difference:", symmetric_difference)

print("Is A a subset of B", A.issubset(B))
print("Is B a superset of A", B.issuperset(A))


X = int(input("Enter a value X to remove from A: "))

A.discard(X)

print("Set A after discard:", A)
# Out:
# Set A: {0, 7, 14, 49, 28}
# Set B: {0, 36, 9, 18, 63}
# Union of A and B: {0, 36, 7, 9, 14, 49, 18, 28, 63}
# Intersection of A and B: {0}
# A - B: {49, 28, 14, 7}
# B - A: {9, 18, 36, 63}
# Symmetric difference: {7, 9, 14, 18, 28, 36, 49, 63}
# Is A a subset of B False
# Is B a superset of A False
# Set A after discard: {0, 14, 49, 28}

# %% [markdown]
# 5. Consider the following dictionary:
# my_dict = {
#  "name": "<your name>",
#  "roll_no": "<your roll number>",
#  "branch": "<your branch>",
#  "age": <your age>,
#  "city": "<your home city>"
# }
# i. Rename the key “city” to “location” without changing its value (do not just recreate the dictionary by
# hand — use pop() or dictionary comprehension so the code would work for any dictionary).
# ii. Add a new key “cgpa” with your CGPA as its value.
# iii. Update the value of “age” by increasing it by 1.
# iv. Delete the “branch” key using two different methods in two separate copies of the dictionary: once
# with pop() and once with the del keyword. Explain in one line how pop() differs from del (hint: what
# does each return?).
# v. Iterate over your dictionary using .items() and print each key-value pair as “key → value”.
# vi. Before accessing a key called “email” (which doesn't exist in your dictionary), check for its existence
# using the in keyword and print a safe fallback message instead of letting the program crash.
# vii. Create a second dictionary friend_dict with the same 5 original keys but a friend's (fictional) details.
# Merge it with your own using the {**dict1, **dict2} syntax, and explain in one line which values “win”
# when both dictionaries share a key.
# viii. Use dictionary comprehension to create a new dictionary containing only the key-value pairs from your
# original dictionary where the value is a string

# %%
my_dict = {
    "name": "Divakar Purohit",
    "roll_no": "1024170422",
    "branch": "COPC",
    "age": 19,
    "city": "PATIALA"
}

print("Original dictionary:")
print(my_dict)

my_dict["location"] = my_dict.pop("city")

print("After renaming city to location:")
print(my_dict)

my_dict["cgpa"] = 9.84

print("After adding CGPA:")
print(my_dict)

my_dict["age"] += 1

print("After increasing age by 1:")
print(my_dict)

dict_using_pop = my_dict.copy()
dict_using_del = my_dict.copy()

removed_branch = dict_using_pop.pop("branch")

print("Using pop():")
print(dict_using_pop)
print("Value returned by pop():", removed_branch)

del dict_using_del["branch"]

print("Using del:")
print(dict_using_del)

print("Key-value pairs:")

for key, value in my_dict.items():
    print(f"{key} : {value}")


if "email" in my_dict:
    print("Email:", my_dict["email"])
else:
    print("mail key does not exist.")

friend_dict = {
    "name": "Sparsh",
    "roll_no": "1024170310",
    "branch": "COPC",
    "age": 20,
    "city": "Amritsar"
}

merged_dict = {**my_dict, **friend_dict}

print("Merged dictionary:")
print(merged_dict)


string_values = {
    key: value
    for key, value in my_dict.items()
    if isinstance(value, str)
}

print("Dictionary containing only string values:")
print(string_values)
# Out:
# Original dictionary:
# {'name': 'Divakar Purohit', 'roll_no': '1024170422', 'branch': 'COPC', 'age': 19, 'city': 'PATIALA'}
# After renaming city to location:
# {'name': 'Divakar Purohit', 'roll_no': '1024170422', 'branch': 'COPC', 'age': 19, 'location': 'PATIALA'}
# After adding CGPA:
# {'name': 'Divakar Purohit', 'roll_no': '1024170422', 'branch': 'COPC', 'age': 19, 'location': 'PATIALA', 'cgpa': 9.84}
# After increasing age by 1:
# {'name': 'Divakar Purohit', 'roll_no': '1024170422', 'branch': 'COPC', 'age': 20, 'location': 'PATIALA', 'cgpa': 9.84}
# Using pop():
# {'name': 'Divakar Purohit', 'roll_no': '1024170422', 'age': 20, 'location': 'PATIALA', 'cgpa': 9.84}
# Value returned by pop(): COPC
# Using del:
# {'name': 'Divakar Purohit', 'roll_no': '1024170422', 'age': 20, 'location': 'PATIALA', 'cgpa': 9.84}
# Key-value pairs:
# name : Divakar Purohit
# roll_no : 1024170422
# branch : COPC
# age : 20
# location : PATIALA
# cgpa : 9.84
# mail key does not exist.
# Merged dictionary:
# {'name': 'Sparsh', 'roll_no': '1024170310', 'branch': 'COPC', 'age': 20, 'location': 'PATIALA', 'cgpa': 9.84, 'city': 'Amritsar'}
# Dictionary containing only string values:
# {'name': 'Divakar Purohit', 'roll_no': '1024170422', 'branch': 'COPC', 'location': 'PATIALA'}
